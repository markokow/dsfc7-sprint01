# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import folium

# %% [markdown]
# #### DATASETS

# %%
#FOR GEOPANDAS
df_sped = pd.read_csv("schools_combined_SPED.csv")
provice_data = gpd.read_file('./Provinces/Provinces/Provinces.shp')

#FOR FOLIUM
geo_data= gpd.read_file('./phl_schp_deped/phl_schp_deped.shp')
geo_data["x"] = geo_data.geometry.centroid.x
geo_data["y"] = geo_data.geometry.centroid.y
# Out:
# <ipython-input-2-5fc7ce034a7b>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo_data["x"] = geo_data.geometry.centroid.x
# <ipython-input-2-5fc7ce034a7b>:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo_data["y"] = geo_data.geometry.centroid.y

# %% [markdown]
# #### GEOPANDAS HEATMAPS

# %%
df_sped
# Out:
#       Unnamed: 0  school.id                     school.name school.region  \
# 0              1     102193   A. P. Santos ES (SPED Center)      Region I
# 1              7     102252           Abanon Central School      Region I
# 2             22     102226         Agdao Integrated School      Region I
# 3             24     101132                         Agno CS      Region I
# 4             29     101149                      Aguilar CS      Region I
# ...          ...        ...                             ...           ...
# 1353       46535     319603  Philippine School for the Deaf           NCR
# 1354       46547     305350                      Quirino HS           NCR
# 1355       46554     305414                        Sagad HS           NCR
# 1356       46571     305446       Sitero Francisco Mem. NHS           NCR
# 1357       46597     305441                  Valenzuela NHS           NCR
#
#            school.region.name      school.province     school.cityhall  \
# 0               Ilocos Region         ILOCOS NORTE        ILOCOS NORTE
# 1               Ilocos Region           PANGASINAN          PANGASINAN
# 2               Ilocos Region           PANGASINAN          PANGASINAN
# 3               Ilocos Region           PANGASINAN          PANGASINAN
# 4               Ilocos Region           PANGASINAN          PANGASINAN
# ...                       ...                  ...                 ...
# 1353  National Capital Region  NCR FOURTH DISTRICT          PASAY CITY
# 1354  National Capital Region  NCR SECOND DISTRICT         QUEZON CITY
# 1355  National Capital Region  NCR SECOND DISTRICT       CITY OF PASIG
# 1356  National Capital Region   NCR THIRD DISTRICT  CITY OF VALENZUELA
# 1357  National Capital Region   NCR THIRD DISTRICT  CITY OF VALENZUELA
#
#              school.division       school.citymuni  \
# 0                 Laoag City  LAOAG CITY (Capital)
# 1            San Carlos City       SAN CARLOS CITY
# 2            San Carlos City       SAN CARLOS CITY
# 3     Pangasinan I, Lingayen                  AGNO
# 4     Pangasinan I, Lingayen               AGUILAR
# ...                      ...                   ...
# 1353              Pasay City            PASAY CITY
# 1354             Quezon City           QUEZON CITY
# 1355              Pasig City         CITY OF PASIG
# 1356         Valenzuela City    CITY OF VALENZUELA
# 1357         Valenzuela City    CITY OF VALENZUELA
#
#                        school.district  ... School ID_y  \
# 0               Laoag City District II  ...    102193.0
# 1          San Carlos City District IV  ...    102252.0
# 2          San Carlos City District II  ...    102226.0
# 3                                 Agno  ...    101132.0
# 4                              Aguilar  ...    101149.0
# ...                                ...  ...         ...
# 1353          Pasay City West District  ...    319603.0
# 1354               School District XIV  ...    305350.0
# 1355             Pasig City District I  ...    305414.0
# 1356  Valenzuela City Central District  ...    305446.0
# 1357  Valenzuela City Central District  ...    305441.0
#
#      rooms.standard.academic rooms.standard.unused rooms.nonstandard.academic  \
# 0                       13.0                   3.0                        0.0
# 1                       24.0                   0.0                        0.0
# 2                       20.0                   0.0                        0.0
# 3                       23.0                   0.0                        0.0
# 4                       18.0                   0.0                        0.0
# ...                      ...                   ...                        ...
# 1353                    25.0                   0.0                        0.0
# 1354                    68.0                   0.0                        0.0
# 1355                    39.0                   0.0                        0.0
# 1356                    16.0                   0.0                        0.0
# 1357                    33.0                   0.0                        0.0
#
#       rooms.nonstandard.unused teachers.instructor teachers.mobile  \
# 0                          0.0                 0.0             2.0
# 1                          0.0                 0.0             4.0
# 2                          0.0                 0.0             4.0
# 3                          0.0                 0.0             6.0
# 4                          0.0                 0.0             4.0
# ...                        ...                 ...             ...
# 1353                       0.0                 0.0             0.0
# 1354                       0.0                 0.0            22.0
# 1355                       0.0                 0.0             7.0
# 1356                       0.0                 0.0             3.0
# 1357                       0.0                 0.0            18.0
#
#      teachers.regular teachers.sped       MOOE
# 0                12.0           4.0   275000.0
# 1                22.0           1.0   440000.0
# 2                20.0           1.0   381000.0
# 3                18.0           1.0   392000.0
# 4                29.0           1.0   536000.0
# ...               ...           ...        ...
# 1353              4.0          89.0  3179000.0
# 1354            121.0           5.0  3204000.0
# 1355             53.0           1.0  2154000.0
# 1356             39.0           0.0  1647000.0
# 1357             84.0           1.0  2924000.0
#
# [1358 rows x 64 columns]

# %%
provice_data.head()
# Out:
#    ID_0  ISO       NAME_0  ID_1            NAME_1 NL_NAME_1 VARNAME_1  \
# 0   177  PHL  Philippines     1              Abra      None      None
# 1   177  PHL  Philippines     2  Agusan del Norte      None      None
# 2   177  PHL  Philippines     3    Agusan del Sur      None      None
# 3   177  PHL  Philippines     4             Aklan      None      None
# 4   177  PHL  Philippines     5             Albay      None      None
#
#                 TYPE_1 ENGTYPE_1          PROVINCE  \
# 0  Lalawigan|Probinsya  Province              Abra
# 1  Lalawigan|Probinsya  Province  Agusan del Norte
# 2  Lalawigan|Probinsya  Province    Agusan del Sur
# 3  Lalawigan|Probinsya  Province             Aklan
# 4  Lalawigan|Probinsya  Province             Albay
#
#                                    REGION  \
# 0  Cordillera Administrative Region (CAR)
# 1                    Caraga (Region XIII)
# 2                    Caraga (Region XIII)
# 3             Western Visayas (Region VI)
# 4                 Bicol Region (Region V)
#
#                                             geometry
# 0  POLYGON ((120.96795 17.95706, 120.97803 17.949...
# 1  POLYGON ((125.57724 9.45679, 125.59687 9.45509...
# 2  POLYGON ((125.91087 8.85625, 125.91461 8.85211...
# 3  MULTIPOLYGON (((122.43667 11.59833, 122.43667 ...
# 4  MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...

# %%
print('SPED df:\n', sorted(df_sped["school.province"].unique()), '\n')
print('province df:\n', sorted(provice_data["PROVINCE"].unique()))
# Out:
# SPED df:
#  ['ABRA', 'AGUSAN DEL NORTE', 'AGUSAN DEL SUR', 'AKLAN', 'ALBAY', 'ANTIQUE', 'APAYAO', 'AURORA', 'BATAAN', 'BATANES', 'BATANGAS', 'BENGUET', 'BILIRAN', 'BOHOL', 'BUKIDNON', 'BULACAN', 'CAGAYAN', 'CAMARINES NORTE', 'CAMARINES SUR', 'CAMIGUIN', 'CAPIZ', 'CATANDUANES', 'CAVITE', 'CEBU', 'CITY OF COTABATO', 'CITY OF ISABELA', 'COMPOSTELA VALLEY', 'DAVAO DEL NORTE', 'DAVAO DEL SUR', 'DAVAO ORIENTAL', 'DINAGAT ISLANDS', 'EASTERN SAMAR', 'GUIMARAS', 'IFUGAO', 'ILOCOS NORTE', 'ILOCOS SUR', 'ILOILO', 'ISABELA', 'KALINGA', 'LA UNION', 'LAGUNA', 'LANAO DEL NORTE', 'LANAO DEL SUR', 'LEYTE', 'MAGUINDANAO', 'MANILA, NCR, FIRST DISTRICT', 'MARINDUQUE', 'MASBATE', 'MISAMIS OCCIDENTAL', 'MISAMIS ORIENTAL', 'MOUNTAIN PROVINCE', 'NCR FOURTH DISTRICT', 'NCR SECOND DISTRICT', 'NCR THIRD DISTRICT', 'NEGROS OCCIDENTAL', 'NEGROS ORIENTAL', 'NORTH COTABATO', 'NORTHERN SAMAR', 'NUEVA ECIJA', 'NUEVA VIZCAYA', 'OCCIDENTAL MINDORO', 'ORIENTAL MINDORO', 'PALAWAN', 'PAMPANGA', 'PANGASINAN', 'QUEZON', 'QUIRINO', 'RIZAL', 'ROMBLON', 'SARANGANI', 'SIQUIJOR', 'SORSOGON', 'SOUTH COTABATO', 'SOUTHERN LEYTE', 'SULTAN KUDARAT', 'SULU', 'SURIGAO DEL NORTE', 'SURIGAO DEL SUR', 'TARLAC', 'WESTERN SAMAR', 'ZAMBALES', 'ZAMBOANGA DEL NORTE', 'ZAMBOANGA DEL SUR', 'ZAMBOANGA SIBUGAY']
#
# province df:
#  ['Abra', 'Agusan del Norte', 'Agusan del Sur', 'Aklan', 'Albay', 'Antique', 'Apayao', 'Aurora', 'Basilan', 'Bataan', 'Batanes', 'Batangas', 'Benguet', 'Biliran', 'Bohol', 'Bukidnon', 'Bulacan', 'Cagayan', 'Camarines Norte', 'Camarines Sur', 'Camiguin', 'Capiz', 'Catanduanes', 'Cavite', 'Cebu', 'Compostela Valley', 'Davao Oriental', 'Davao del Norte', 'Davao del Sur', 'Dinagat Islands', 'Eastern Samar', 'Guimaras', 'Ifugao', 'Ilocos Norte', 'Ilocos Sur', 'Iloilo', 'Isabela', 'Kalinga', 'La Union', 'Laguna', 'Lanao del Norte', 'Lanao del Sur', 'Leyte', 'Maguindanao', 'Marinduque', 'Masbate', 'Metropolitan Manila', 'Misamis Occidental', 'Misamis Oriental', 'Mountain Province', 'Negros Occidental', 'Negros Oriental', 'North Cotabato', 'Northern Samar', 'Nueva Ecija', 'Nueva Vizcaya', 'Occidental Mindoro', 'Oriental Mindoro', 'Palawan', 'Pampanga', 'Pangasinan', 'Quezon', 'Quirino', 'Rizal', 'Romblon', 'Samar', 'Sarangani', 'Shariff Kabunsuan', 'Siquijor', 'Sorsogon', 'South Cotabato', 'Southern Leyte', 'Sultan Kudarat', 'Sulu', 'Surigao del Norte', 'Surigao del Sur', 'Tarlac', 'Tawi-Tawi', 'Zambales', 'Zamboanga Sibugay', 'Zamboanga del Norte', 'Zamboanga del Sur']

# %%
province_dic = {'CITY OF COTABATO':'Maguindanao',
 'Manila, Ncr, First District':"Metropolitan Manila",
 'Ncr Fourth District':"Metropolitan Manila",
 'Ncr Second District':"Metropolitan Manila",
 'Ncr Third District':"Metropolitan Manila",
 'CITY OF ISABELA':"Basilan"}

# %%
df_sped["school.province"] = df_sped["school.province"].str.title().replace(province_dic).str.replace("Del", 'del')
df_sped.columns
# Out:
# Index(['Unnamed: 0', 'school.id', 'school.name', 'school.region',
#        'school.region.name', 'school.province', 'school.cityhall',
#        'school.division', 'school.citymuni', 'school.district',
#        'school.legdistrict', 'school.type', 'school.abbrev',
#        'school.previousname', 'school.mother.id', 'school.address',
#        'school.established', 'school.classification', 'school.classification2',
#        'school.curricularclass', 'school.organization', 'school.cityincome',
#        'school.cityclass', 'school.urban', 'School ID_x', 'Kinder Male',
#        'Kinder Female', 'Grade 1 Male', 'Grade 1 Female', 'Grade 2 Male',
#        'Grade 2 Female', 'Grade 3 Male', 'Grade 3 Female', 'Grade 4 Male',
#        'Grade 4 Female', 'Grade 5 Male', 'Grade 5 Female', 'Grade 6 Male',
#        'Grade 6 Female', 'SPED NG Male', 'SPED NG Female', 'Grade 7 Male',
#        'Grade 7 Female', 'Grade 8 Male', 'Grade 8 Female', 'Grade 9 Male',
#        'Grade 9 Female', 'Grade 10 Male', 'Grade 10 Female', 'Grade 11 Male',
#        'Grade 11 Female', 'Grade 12 Male', 'Grade 12 Female', ' school.mooe ',
#        'School ID_y', 'rooms.standard.academic', 'rooms.standard.unused',
#        'rooms.nonstandard.academic', 'rooms.nonstandard.unused',
#        'teachers.instructor', 'teachers.mobile', 'teachers.regular',
#        'teachers.sped', 'MOOE'],
#       dtype='object')

# %%
sped_province = df_sped.groupby("school.province")["school.id"].nunique().reset_index()
sped_province
# Out:
#         school.province  school.id
# 0                  Abra          1
# 1      Agusan del Norte         17
# 2        Agusan del Sur         22
# 3                 Aklan          7
# 4                 Albay         16
# ..                  ...        ...
# 76        Western Samar         11
# 77             Zambales         30
# 78    Zamboanga Sibugay         12
# 79  Zamboanga del Norte         11
# 80    Zamboanga del Sur         54
#
# [81 rows x 2 columns]

# %%
merged_data = pd.merge(provice_data,sped_province,left_on="PROVINCE",right_on="school.province",how ="left").fillna(0)
merged_data.sort_values("school.id",ascending=False).head(10)
# Out:
#     ID_0  ISO       NAME_0  ID_1               NAME_1  NL_NAME_1 VARNAME_1  \
# 46   177  PHL  Philippines    47  Metropolitan Manila          0         0
# 60   177  PHL  Philippines    61           Pangasinan          0         0
# 11   177  PHL  Philippines    12             Batangas          0         0
# 80   177  PHL  Philippines    81    Zamboanga del Sur          0         0
# 61   177  PHL  Philippines    62               Quezon          0         0
# 24   177  PHL  Philippines    25                 Cebu          0         0
# 51   177  PHL  Philippines    52      Negros Oriental          0         0
# 35   177  PHL  Philippines    36               Iloilo          0         0
# 57   177  PHL  Philippines    58     Oriental Mindoro          0         0
# 27   177  PHL  Philippines    28        Davao del Sur          0         0
#
#                  TYPE_1 ENGTYPE_1             PROVINCE  \
# 46  Lalawigan|Probinsya  Province  Metropolitan Manila
# 60  Lalawigan|Probinsya  Province           Pangasinan
# 11  Lalawigan|Probinsya  Province             Batangas
# 80  Lalawigan|Probinsya  Province    Zamboanga del Sur
# 61  Lalawigan|Probinsya  Province               Quezon
# 24  Lalawigan|Probinsya  Province                 Cebu
# 51  Lalawigan|Probinsya  Province      Negros Oriental
# 35  Lalawigan|Probinsya  Province               Iloilo
# 57  Lalawigan|Probinsya  Province     Oriental Mindoro
# 27  Lalawigan|Probinsya  Province        Davao del Sur
#
#                              REGION  \
# 46              Metropolitan Manila
# 60         Ilocos Region (Region I)
# 11         CALABARZON (Region IV-A)
# 80  Zamboanga Peninsula (Region IX)
# 61         CALABARZON (Region IV-A)
# 24     Central Visayas (Region VII)
# 51     Central Visayas (Region VII)
# 35      Western Visayas (Region VI)
# 57           MIMAROPA (Region IV-B)
# 27         Davao Region (Region XI)
#
#                                              geometry      school.province  \
# 46  MULTIPOLYGON (((120.97972 14.49306, 120.98000 ...  Metropolitan Manila
# 60  MULTIPOLYGON (((119.86505 15.81170, 119.86479 ...           Pangasinan
# 11  MULTIPOLYGON (((121.08528 13.57333, 121.08556 ...             Batangas
# 80  MULTIPOLYGON (((122.06223 6.87278, 122.06250 6...    Zamboanga del Sur
# 61  MULTIPOLYGON (((125.22166 10.43444, 125.22195 ...               Quezon
# 24  MULTIPOLYGON (((123.38955 9.43467, 123.39031 9...                 Cebu
# 51  MULTIPOLYGON (((123.27111 9.08476, 123.27173 9...      Negros Oriental
# 35  MULTIPOLYGON (((122.77306 10.93785, 122.77243 ...               Iloilo
# 57  MULTIPOLYGON (((121.43574 12.20257, 121.43555 ...     Oriental Mindoro
# 27  MULTIPOLYGON (((125.39778 5.43583, 125.39778 5...        Davao del Sur
#
#     school.id
# 46      143.0
# 60       68.0
# 11       55.0
# 80       54.0
# 61       52.0
# 24       52.0
# 51       43.0
# 35       43.0
# 57       42.0
# 27       35.0

# %%
sped_corr=df_sped.fillna("Urban")

# %%
sped_dist = sped_corr.groupby("school.urban")["school.id"].nunique().sort_values()
# indicates if plotting on the figues or on subplots
#modify lang yung size ng graph mo.L,W format
plt.figure(figsize=(12,6)) 

# the main code to create the graph
plt.bar(sped_dist.index, sped_dist.values) 

# additional elements that can be customzed
plt.title("SPED Schools based on Urban Type", fontsize=16)
plt.ylabel("Number of SPED Schools", fontsize=12)
plt.xlabel("Urban Type", fontsize=12)
year = ['Rural','Urban','Partially Urban']
plt.xticks(range(len(sped_dist.index)), year)

# display graph
plt.show()

# %%
## OVERALL SPED

# set a variable that will call whatever column we want to visualise on the map
variable = 'school.id'
# set the range for the choropleth
vmin, vmax = merged_data["school.id"].min(), merged_data["school.id"].max()
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(15, 10))

# Complete the code
merged_data.plot(column=variable, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)

sm = plt.cm.ScalarMappable(cmap='Oranges', norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)

# %%
## filling NA values
sped_corr=df_sped.fillna("Urban")
sped_corr.groupby("school.urban")["school.id"].nunique()
# Out:
# school.urban
# Partially Urban    1009
# Rural                30
# Urban               319
# Name: school.id, dtype: int64

# %%
sped_urban = sped_corr[sped_corr["school.urban"] =="Urban"]
sped_part_urban = sped_corr[sped_corr["school.urban"] =="Partially Urban"]
sped_rural = sped_corr[sped_corr["school.urban"] =="Rural"]

# %%
#SPED URBAN
sped_province_U = sped_urban.groupby("school.province")["school.id"].nunique().reset_index()
merged_data_U = pd.merge(provice_data,sped_province_U,left_on="PROVINCE",right_on="school.province",how ="left").fillna(0)

# set a variable that will call whatever column we want to visualise on the map
variable = 'school.id'
# set the range for the choropleth
vmin, vmax = merged_data_U["school.id"].min(), merged_data_U["school.id"].max()
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(15, 10))

# Complete the code
merged_data.plot(column=variable, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)

sm = plt.cm.ScalarMappable(cmap='Oranges', norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)

# %%
#SPED PARTIAL URBAN
sped_province_PU = sped_part_urban.groupby("school.province")["school.id"].nunique().reset_index()
merged_data_PU = pd.merge(provice_data,sped_province_PU,left_on="PROVINCE",right_on="school.province",how ="left").fillna(0)

# set a variable that will call whatever column we want to visualise on the map
variable = 'school.id'
# set the range for the choropleth
vmin, vmax = merged_data_PU["school.id"].min(), merged_data_PU["school.id"].max()
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(15, 10))

# Complete the code
merged_data.plot(column=variable, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)

sm = plt.cm.ScalarMappable(cmap='Oranges', norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)

# %%
#SPED RURAL
sped_province_R = sped_rural.groupby("school.province")["school.id"].nunique().reset_index()
merged_data_R = pd.merge(provice_data,sped_province_R,left_on="PROVINCE",right_on="school.province",how ="left").fillna(0)

# set a variable that will call whatever column we want to visualise on the map
variable = 'school.id'
# set the range for the choropleth
vmin, vmax = merged_data_R["school.id"].min(), merged_data_R["school.id"].max()
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(15, 10))

# Complete the code
merged_data.plot(column=variable, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)

sm = plt.cm.ScalarMappable(cmap='Oranges', norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)

# %% [markdown]
# #### FOLIUM

# %%
fol_sped = pd.merge(df_sped,geo_data,left_on="School ID_y", right_on = "ID",how ="left")
fol_sped
# Out:
#       Unnamed: 0  school.id                     school.name school.region  \
# 0              1     102193   A. P. Santos ES (SPED Center)      Region I
# 1              7     102252           Abanon Central School      Region I
# 2             22     102226         Agdao Integrated School      Region I
# 3             24     101132                         Agno CS      Region I
# 4             29     101149                      Aguilar CS      Region I
# ...          ...        ...                             ...           ...
# 1357       46535     319603  Philippine School for the Deaf           NCR
# 1358       46547     305350                      Quirino HS           NCR
# 1359       46554     305414                        Sagad HS           NCR
# 1360       46571     305446       Sitero Francisco Mem. NHS           NCR
# 1361       46597     305441                  Valenzuela NHS           NCR
#
#            school.region.name      school.province     school.cityhall  \
# 0               Ilocos Region         Ilocos Norte        ILOCOS NORTE
# 1               Ilocos Region           Pangasinan          PANGASINAN
# 2               Ilocos Region           Pangasinan          PANGASINAN
# 3               Ilocos Region           Pangasinan          PANGASINAN
# 4               Ilocos Region           Pangasinan          PANGASINAN
# ...                       ...                  ...                 ...
# 1357  National Capital Region  Metropolitan Manila          PASAY CITY
# 1358  National Capital Region  Metropolitan Manila         QUEZON CITY
# 1359  National Capital Region  Metropolitan Manila       CITY OF PASIG
# 1360  National Capital Region  Metropolitan Manila  CITY OF VALENZUELA
# 1361  National Capital Region  Metropolitan Manila  CITY OF VALENZUELA
#
#              school.division       school.citymuni  \
# 0                 Laoag City  LAOAG CITY (Capital)
# 1            San Carlos City       SAN CARLOS CITY
# 2            San Carlos City       SAN CARLOS CITY
# 3     Pangasinan I, Lingayen                  AGNO
# 4     Pangasinan I, Lingayen               AGUILAR
# ...                      ...                   ...
# 1357              Pasay City            PASAY CITY
# 1358             Quezon City           QUEZON CITY
# 1359              Pasig City         CITY OF PASIG
# 1360         Valenzuela City    CITY OF VALENZUELA
# 1361         Valenzuela City    CITY OF VALENZUELA
#
#                        school.district  ... Total_Inst Color_Code  \
# 0               Laoag City District II  ...        NaN        NaN
# 1          San Carlos City District IV  ...       24.0       Blue
# 2          San Carlos City District II  ...       21.0       Blue
# 3                                 Agno  ...       24.0       Blue
# 4                              Aguilar  ...       30.0       Blue
# ...                                ...  ...        ...        ...
# 1357          Pasay City West District  ...       84.0       Blue
# 1358               School District XIV  ...       74.0       Blue
# 1359             Pasig City District I  ...       40.0        Red
# 1360  Valenzuela City Central District  ...       16.0        Red
# 1361  Valenzuela City Central District  ...       38.0        Red
#
#                     Barangay             Province  \
# 0                        NaN                  NaN
# 1                     Abanon           PANGASINAN
# 2                      Agdao           PANGASINAN
# 3             POBLACION WEST           PANGASINAN
# 4                  POBLACION           PANGASINAN
# ...                      ...                  ...
# 1357                    None  NCR FOURTH DISTRICT
# 1358  Project 3, Duyan Duyan  NCR SECOND DISTRICT
# 1359                   Sagad  NCR SECOND DISTRICT
# 1360                   Ugong   NCR THIRD DISTRICT
# 1361                 Marulas   NCR THIRD DISTRICT
#
#                               District              Type_of_Sc  \
# 0                                  NaN                     NaN
# 1          San Carlos City District IV  School with no Annexes
# 2          San Carlos City District II  School with no Annexes
# 3                                 Agno  School with no Annexes
# 4                              Aguilar  School with no Annexes
# ...                                ...                     ...
# 1357          Pasay City West District  School with no Annexes
# 1358               School District XIV  School with no Annexes
# 1359             Pasig City District I  School with no Annexes
# 1360  Valenzuela City Central District  School with no Annexes
# 1361  Valenzuela City Central District           Mother school
#
#                  GPS_Source                              geometry           x  \
# 0                       NaN                                  None         NaN
# 1        GPS Pinning (2012)  POINT Z (120.32827 15.86601 0.00000)  120.328272
# 2        GPS Pinning (2012)  POINT Z (120.32322 15.89085 0.00000)  120.323217
# 3     GPS Pinning (2009-10)  POINT Z (119.79667 16.11833 0.00000)  119.796667
# 4     GPS Pinning (2009-10)  POINT Z (120.23778 15.88528 0.00000)  120.237778
# ...                     ...                                   ...         ...
# 1357     GPS Pinning (2012)  POINT Z (120.99517 14.54214 0.00000)  120.995169
# 1358  GPS Pinning (2009-10)  POINT Z (121.06618 14.63215 0.00000)  121.066177
# 1359  GPS Pinning (2009-10)  POINT Z (121.07972 14.56611 0.00000)  121.079722
# 1360  GPS Pinning (2009-10)  POINT Z (121.00667 14.68917 0.00000)  121.006667
# 1361  GPS Pinning (2009-10)  POINT Z (120.98337 14.67387 0.00000)  120.983368
#
#               y
# 0           NaN
# 1     15.866006
# 2     15.890847
# 3     16.118333
# 4     15.885278
# ...         ...
# 1357  14.542143
# 1358  14.632148
# 1359  14.566111
# 1360  14.689167
# 1361  14.673871
#
# [1362 rows x 82 columns]

# %%
fol_filtered = fol_sped[fol_sped['geometry'].notnull()]
fol_filtered
# Out:
#       Unnamed: 0  school.id                     school.name school.region  \
# 1              7     102252           Abanon Central School      Region I
# 2             22     102226         Agdao Integrated School      Region I
# 3             24     101132                         Agno CS      Region I
# 4             29     101149                      Aguilar CS      Region I
# 6             98     102227           Ano Elementary School      Region I
# ...          ...        ...                             ...           ...
# 1357       46535     319603  Philippine School for the Deaf           NCR
# 1358       46547     305350                      Quirino HS           NCR
# 1359       46554     305414                        Sagad HS           NCR
# 1360       46571     305446       Sitero Francisco Mem. NHS           NCR
# 1361       46597     305441                  Valenzuela NHS           NCR
#
#            school.region.name      school.province     school.cityhall  \
# 1               Ilocos Region           Pangasinan          PANGASINAN
# 2               Ilocos Region           Pangasinan          PANGASINAN
# 3               Ilocos Region           Pangasinan          PANGASINAN
# 4               Ilocos Region           Pangasinan          PANGASINAN
# 6               Ilocos Region           Pangasinan          PANGASINAN
# ...                       ...                  ...                 ...
# 1357  National Capital Region  Metropolitan Manila          PASAY CITY
# 1358  National Capital Region  Metropolitan Manila         QUEZON CITY
# 1359  National Capital Region  Metropolitan Manila       CITY OF PASIG
# 1360  National Capital Region  Metropolitan Manila  CITY OF VALENZUELA
# 1361  National Capital Region  Metropolitan Manila  CITY OF VALENZUELA
#
#              school.division     school.citymuni  \
# 1            San Carlos City     SAN CARLOS CITY
# 2            San Carlos City     SAN CARLOS CITY
# 3     Pangasinan I, Lingayen                AGNO
# 4     Pangasinan I, Lingayen             AGUILAR
# 6            San Carlos City     SAN CARLOS CITY
# ...                      ...                 ...
# 1357              Pasay City          PASAY CITY
# 1358             Quezon City         QUEZON CITY
# 1359              Pasig City       CITY OF PASIG
# 1360         Valenzuela City  CITY OF VALENZUELA
# 1361         Valenzuela City  CITY OF VALENZUELA
#
#                        school.district  ... Total_Inst Color_Code  \
# 1          San Carlos City District IV  ...       24.0       Blue
# 2          San Carlos City District II  ...       21.0       Blue
# 3                                 Agno  ...       24.0       Blue
# 4                              Aguilar  ...       30.0       Blue
# 6          San Carlos City District II  ...       10.0       Blue
# ...                                ...  ...        ...        ...
# 1357          Pasay City West District  ...       84.0       Blue
# 1358               School District XIV  ...       74.0       Blue
# 1359             Pasig City District I  ...       40.0        Red
# 1360  Valenzuela City Central District  ...       16.0        Red
# 1361  Valenzuela City Central District  ...       38.0        Red
#
#                     Barangay             Province  \
# 1                     Abanon           PANGASINAN
# 2                      Agdao           PANGASINAN
# 3             POBLACION WEST           PANGASINAN
# 4                  POBLACION           PANGASINAN
# 6                        Ano           PANGASINAN
# ...                      ...                  ...
# 1357                    None  NCR FOURTH DISTRICT
# 1358  Project 3, Duyan Duyan  NCR SECOND DISTRICT
# 1359                   Sagad  NCR SECOND DISTRICT
# 1360                   Ugong   NCR THIRD DISTRICT
# 1361                 Marulas   NCR THIRD DISTRICT
#
#                               District              Type_of_Sc  \
# 1          San Carlos City District IV  School with no Annexes
# 2          San Carlos City District II  School with no Annexes
# 3                                 Agno  School with no Annexes
# 4                              Aguilar  School with no Annexes
# 6          San Carlos City District II  School with no Annexes
# ...                                ...                     ...
# 1357          Pasay City West District  School with no Annexes
# 1358               School District XIV  School with no Annexes
# 1359             Pasig City District I  School with no Annexes
# 1360  Valenzuela City Central District  School with no Annexes
# 1361  Valenzuela City Central District           Mother school
#
#                  GPS_Source                              geometry           x  \
# 1        GPS Pinning (2012)  POINT Z (120.32827 15.86601 0.00000)  120.328272
# 2        GPS Pinning (2012)  POINT Z (120.32322 15.89085 0.00000)  120.323217
# 3     GPS Pinning (2009-10)  POINT Z (119.79667 16.11833 0.00000)  119.796667
# 4     GPS Pinning (2009-10)  POINT Z (120.23778 15.88528 0.00000)  120.237778
# 6        GPS Pinning (2012)  POINT Z (120.38029 15.95083 0.00000)  120.380292
# ...                     ...                                   ...         ...
# 1357     GPS Pinning (2012)  POINT Z (120.99517 14.54214 0.00000)  120.995169
# 1358  GPS Pinning (2009-10)  POINT Z (121.06618 14.63215 0.00000)  121.066177
# 1359  GPS Pinning (2009-10)  POINT Z (121.07972 14.56611 0.00000)  121.079722
# 1360  GPS Pinning (2009-10)  POINT Z (121.00667 14.68917 0.00000)  121.006667
# 1361  GPS Pinning (2009-10)  POINT Z (120.98337 14.67387 0.00000)  120.983368
#
#               y
# 1     15.866006
# 2     15.890847
# 3     16.118333
# 4     15.885278
# 6     15.950833
# ...         ...
# 1357  14.542143
# 1358  14.632148
# 1359  14.566111
# 1360  14.689167
# 1361  14.673871
#
# [769 rows x 82 columns]

# %%
# Coordinates to show
map_center = [14.583197, 121.051538]

# Styling the map
mymap = folium.Map(location=map_center, height=700, width=1000, tiles="OpenStreetMap", zoom_start=14)

# %%
from folium.plugins import MarkerCluster
mymap_cluster = folium.Map(location=map_center, height=700, width=1000, tiles="OpenStreetMap", zoom_start=13)
marker_cluster = MarkerCluster().add_to(mymap_cluster)

# %%
#DISCLAIMER: 769 out of 1362 schools only has geo data available!!!

for i in np.arange(len(fol_filtered)):
    lat = fol_filtered["y"].values[i]
    lon = fol_filtered["x"].values[i]
    name = fol_filtered["school.name"].values[i]
    folium.Marker([lat,lon], popup=name).add_to(marker_cluster)
    
mymap_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_90ee21ecae4c42a19f039520a5b70a15%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%201000.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20700.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_90ee21ecae4c42a19f039520a5b70a15%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C ...
